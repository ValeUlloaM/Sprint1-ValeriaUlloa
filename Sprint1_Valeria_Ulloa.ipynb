# %%
import pandas as pd
import numpy as np
pd.__version__
np.__version__

db = pd.read_csv('Sprint1.csv')

def ordenar (caracteristica, ascendente):

  dbordenada = 0

  if ascendente == True:
      dbordenada = db.sort_values(by=caracteristica);
  elif ascendente == False:
      dbordenada = db.sort_values(by=caracteristica, ascending = False)
  else:
      dbordenada = "Término que no es compatible";

  print(dbordenada);
  printed()

def printed():
  print("----------------------------------------")
  print("Escribe la variable con la que deseas filtrar la información: \nNA: Por orden alfabético ascendente \nND: Por orden alfabético descendente \nEA: Por edad de menor a mayor edad \nED: por personas de mayor a menor edad \nBA: De menor a mayor puntaje frente al Broccoli \nBD De mayor a menor puntaje frente al Broccoli")
  print("----------------------------------------")
  user_input = input()

  if user_input == 'NA':
    ordenar('Nombre', True)
  elif user_input == 'ND':
    ordenar('Nombre', False)
  elif user_input == 'EA':
    ordenar('Edad', True)
  elif user_input == 'ED':
    ordenar('Edad', False)
  elif user_input == 'BA':
    ordenar('Gusto_broccoli', True)
  elif user_input == 'BD':
    ordenar('Gusto_broccoli', False)
  else:
    print("El término ingresado no es válido, seleccione uno de los mencionados en las instrucciones")

print(db)
printed()
# Out:
#        Nombre  Edad  Gusto_broccoli
# 0    Valeria     25               5
# 1   Christian    20               2
# 2      Julian    22               1
# 3       Mateo    24               7
# 4       Jorge    30               5
# 5   Alejandro    23               3
# 6      Carlos    21               7
# 7       Laura    24               6
# 8     Mariana    19               0
# 9     Nicolás    22               4
# 10    Manuela    23               8
# 11    Natalia    26               3
# 12     Felipe    27              10
# 13      David    25               9
# 14  Valentina    24               5
# 15      Pablo    22               8
# 16       Juan    26               2
# 17  Alejandro    24              10
# 18    Liliana    30               3
# ----------------------------------------
# Escribe la variable con la que deseas filtrar la información:
# NA: Por orden alfabético ascendente
# ND: Por orden alfabético descendente
# EA: Por edad de menor a mayor edad
# ED: por personas de mayor a menor edad
# BA: De menor a mayor puntaje frente al Broccoli
# BD De mayor a menor puntaje frente al Broccoli
# ----------------------------------------
# NA
#        Nombre  Edad  Gusto_broccoli
# 5   Alejandro    23               3
# 17  Alejandro    24              10
# 6      Carlos    21               7
# 1   Christian    20               2
# 13      David    25               9
# 12     Felipe    27              10
# 4       Jorge    30               5
# 16       Juan    26               2
# 2      Julian    22               1
# 7       Laura    24               6
# 18    Liliana    30               3
# 10    Manuela    23               8
# 8     Mariana    19               0
# 3       Mateo    24               7
# 11    Natalia    26               3
# 9     Nicolás    22               4
# 15      Pablo    22               8
# 14  Valentina    24               5
# 0    Valeria     25               5
# ----------------------------------------
# Escribe la variable con la que deseas filtrar la información:
# NA: Por orden alfabético ascendente
# ND: Por orden alfabético descendente
# EA: Por edad de menor a mayor edad
# ED: por personas de mayor a menor edad
# BA: De menor a mayor puntaje frente al Broccoli
# BD De mayor a menor puntaje frente al Broccoli
# ----------------------------------------
# ND
#        Nombre  Edad  Gusto_broccoli
# 0    Valeria     25               5
# 14  Valentina    24               5
# 15      Pablo    22               8
# 9     Nicolás    22               4
# 11    Natalia    26               3
# 3       Mateo    24               7
# 8     Mariana    19               0
# 10    Manuela    23               8
# 18    Liliana    30               3
# 7       Laura    24               6
# 2      Julian    22               1
# 16       Juan    26               2
# 4       Jorge    30               5
# 12     Felipe    27              10
# 13      David    25               9
# 1   Christian    20               2
# 6      Carlos    21               7
# 5   Alejandro    23               3
# 17  Alejandro    24              10
# ----------------------------------------
# Escribe la variable con la que deseas filtrar la información:
# NA: Por orden alfabético ascendente
# ND: Por orden alfabético descendente
# EA: Por edad de menor a mayor edad
# ED: por personas de mayor a menor edad
# BA: De menor a mayor puntaje frente al Broccoli
# BD De mayor a menor puntaje frente al Broccoli
# ----------------------------------------
# EA
#        Nombre  Edad  Gusto_broccoli
# 8     Mariana    19               0
# 1   Christian    20               2
# 6      Carlos    21               7
# 9     Nicolás    22               4
# 2      Julian    22               1
# 15      Pablo    22               8
# 5   Alejandro    23               3
# 10    Manuela    23               8
# 3       Mateo    24               7
# 7       Laura    24               6
# 17  Alejandro    24              10
# 14  Valentina    24               5
# 13      David    25               9
# 0    Valeria     25               5
# 11    Natalia    26               3
# 16       Juan    26               2
# 12     Felipe    27              10
# 4       Jorge    30               5
# 18    Liliana    30               3
# ----------------------------------------
# Escribe la variable con la que deseas filtrar la información:
# NA: Por orden alfabético ascendente
# ND: Por orden alfabético descendente
# EA: Por edad de menor a mayor edad
# ED: por personas de mayor a menor edad
# BA: De menor a mayor puntaje frente al Broccoli
# BD De mayor a menor puntaje frente al Broccoli
# ----------------------------------------
# ED
#        Nombre  Edad  Gusto_broccoli
# 18    Liliana    30               3
# 4       Jorge    30               5
# 12     Felipe    27              10
# 11    Natalia    26               3
# 16       Juan    26               2
# 13      David    25               9
# 0    Valeria     25               5
# 7       Laura    24               6
# 3       Mateo    24               7
# 14  Valentina    24               5
# 17  Alejandro    24              10
# 10    Manuela    23               8
# 5   Alejandro    23               3
# 15      Pablo    22               8
# 2      Julian    22               1
# 9     Nicolás    22               4
# 6      Carlos    21               7
# 1   Christian    20               2
# 8     Mariana    19               0
# ----------------------------------------
# Escribe la variable con la que deseas filtrar la información:
# NA: Por orden alfabético ascendente
# ND: Por orden alfabético descendente
# EA: Por edad de menor a mayor edad
# ED: por personas de mayor a menor edad
# BA: De menor a mayor puntaje frente al Broccoli
# BD De mayor a menor puntaje frente al Broccoli
# ----------------------------------------
# BA
#        Nombre  Edad  Gusto_broccoli
# 8     Mariana    19               0
# 2      Julian    22               1
# 1   Christian    20               2
# 16       Juan    26               2
# 18    Liliana    30               3
# 11    Natalia    26               3
# 5   Alejandro    23               3
# 9     Nicolás    22               4
# 4       Jorge    30               5
# 14  Valentina    24               5
# 0    Valeria     25               5
# 7       Laura    24               6
# 6      Carlos    21               7
# 3       Mateo    24               7
# 10    Manuela    23               8
# 15      Pablo    22               8
# 13      David    25               9
# 17  Alejandro    24              10
# 12     Felipe    27              10
# ----------------------------------------
# Escribe la variable con la que deseas filtrar la información:
# NA: Por orden alfabético ascendente
# ND: Por orden alfabético descendente
# EA: Por edad de menor a mayor edad
# ED: por personas de mayor a menor edad
# BA: De menor a mayor puntaje frente al Broccoli
# BD De mayor a menor puntaje frente al Broccoli
# ----------------------------------------
# BD
#        Nombre  Edad  Gusto_broccoli
# 12     Felipe    27              10
# 17  Alejandro    24              10
# 13      David    25               9
# 15      Pablo    22               8
# 10    Manuela    23               8
# 3       Mateo    24               7
# 6      Carlos    21               7
# 7       Laura    24               6
# 0    Valeria     25               5
# 4       Jorge    30               5
# 14  Valentina    24               5
# 9     Nicolás    22               4
# 11    Natalia    26               3
# 5   Alejandro    23               3
# 18    Liliana    30               3
# 1   Christian    20               2
# 16       Juan    26               2
# 2      Julian    22               1
# 8     Mariana    19               0
# ----------------------------------------
# Escribe la variable con la que deseas filtrar la información:
# NA: Por orden alfabético ascendente
# ND: Por orden alfabético descendente
# EA: Por edad de menor a mayor edad
# ED: por personas de mayor a menor edad
# BA: De menor a mayor puntaje frente al Broccoli
# BD De mayor a menor puntaje frente al Broccoli
# ----------------------------------------
